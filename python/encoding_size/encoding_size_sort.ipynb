# %%
import json
import os
import sys
import math
import datetime
import pathlib

dir_path = pathlib.Path(os.path.abspath('')).resolve()
print(dir_path)
HOME_DIR = str(dir_path).split('/OpenFormat')[0]

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

PROJ_SRC_DIR = f'{HOME_DIR}/OpenFormat/OpenFormat-Public'
sys.path.insert(1, f'{PROJ_SRC_DIR}')
from python.scripts.utils import *
# Out:
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/encoding_size

# %%
num_rows = 1000 * 1000
num_cols = 20
sort_list = [
0.01,
        0.2,
        0.4,
        0.6,
        0.8,
        1
    ]
type_list = ['int', 'float', 'string']

# %%
# %%time
# generate csv files
os.chdir(f'{PROJ_SRC_DIR}/benchmark/generator_v2')
# !pwd
for t in type_list:
    print(t)
    for s in sort_list:
        print(s)
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        if os.path.exists(f'{dir_path}/{base_name}'):
            continue
        os.system(f'python3 gen_workloads.py \
            {t} {num_rows} {num_cols} {base_name} sort {s}')
        os.system(f'cp -r {base_name} {dir_path} && \
            rm -r {base_name}')
os.chdir(dir_path)
# !pwd
# Out:
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/benchmark/generator_v2
# int
# 0.01
# 0.2
# 0.4
# 0.6
# 0.8
# 1
# float
# 0.01
# 0.2
# 0.4
# 0.6
# 0.8
# 1
# string
# 0.01
# 0.2
# 0.4
# 0.6
# 0.8
# 1
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/encoding_size
# CPU times: user 14.8 ms, sys: 17.4 ms, total: 32.2 ms
# Wall time: 274 ms

# %%
pq_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/pq_encoding.json')
orc_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/orc_encoding.json')
pq_name_suffix = '_' + "_".join([str(i) for i in list(pq_config[0].values())]) + '.parquet'
orc_name_suffix = '_' + "_".join([str(i) for i in list(orc_config[0].values())]) + '.orc'
print(pq_config)
# Out:
# loading config from /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/experiments/pq_encoding.json ...
# loading config from /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/experiments/orc_encoding.json ...
# [{'compression': 'NONE', 'use_dictionary': True, 'dictionary_pagesize_limit': 2147483647, 'version': '2.6', 'data_page_version': '2.0'}]

# %%
# generate parquet and orc files
my_password = ''
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        os.system(f'cp {dir_path}/{base_name}/gen_data/{base_name}.csv data_gen')
        os.system(f'echo {my_password} | sudo -S /home/haoyuq/miniconda3/envs/gen/bin/python scripts/parquet_exp.py {base_name} pq_encoding -r=false -o=false')
        os.system(f'echo {my_password} | sudo -S /home/haoyuq/miniconda3/envs/gen/bin/python scripts/orc_exp.py {base_name} orc_encoding -r=false -o=false')
        # orc_schema = open(f'encoding/{base_name}/gen_data/{base_name}_orc_schema.txt', 'r').read()
        # os.system(f'{HOME_DIR}/orc/build/tools/src/csv-import \"{orc_schema}\" \
        #         encoding/{base_name}/gen_data/{base_name}.csv {base_name}.orc')
        os.system(f'mv {base_name}{pq_name_suffix} {dir_path}/{base_name}.parquet')
        os.system(f'mv {base_name}{orc_name_suffix} {dir_path}/{base_name}.orc')
        # os.system(f'mv {base_name}.orc encoding/{base_name}.orc')
os.chdir(dir_path)
# Out:
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7961890697479248
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 6.936979055404663
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.926306962966919
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 6.997570514678955
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.771773099899292
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 2.8322525024414062
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7505037784576416
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 2.6581666469573975
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.6228101253509521
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.2669079303741455
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.6587510108947754
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 1.9544217586517334
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.3903467655181885
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 17.151174545288086
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.226574182510376
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 12.983933925628662
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.1549479961395264
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 10.209222316741943
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.9772617816925049
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 5.984558343887329
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.6945998668670654
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 3.289808511734009
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7201893329620361
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 3.200880289077759
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 2.728269577026367
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 26.601486444473267
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.55735445022583
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 13.52505087852478
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.4613354206085205
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 10.992557525634766
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.864384651184082
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 3.663471221923828
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7030735015869141
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 2.5473039150238037
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 0.7474527359008789
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 2.302100658416748

# %%
import yaml
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        arrow_schema_name = f'encoding_size/{base_name}/gen_data/{base_name}_arrow_schema.txt'
        with open(arrow_schema_name, 'r') as f:
            lines = f.readlines()
        columns = []
        cnt = 0
        for line in lines:
            if 'message' in line or '}' in line or len(line)==0:
                print(line)
                continue
            col_name = f'col{cnt}'
            col_type = None
            if 'String' in line:
                col_type = 'string'
            elif 'int' in line:
                col_type = 'integer'
            elif 'double' in line:
                col_type = 'double'
            if col_type is None:
                print(line)
                col_type = 'skip'
            cnt += 1
            columns.append({'name': col_name, 'type':col_type})
        with open(f'encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml','w') as f:
            yaml.dump({'columns':columns}, f)
# Out:
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }

# %%
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        os.system(f'mkdir encoding_size/{base_name}/gen_data/binary')
        os.system(f'mkdir encoding_size/{base_name}/gen_data/btr')
    
        os.system(f'~/btrblocks/build/csvtobtr -create_binary -binary encoding_size/{base_name}/gen_data/binary/ -csv encoding_size/{base_name}/gen_data/{base_name}.csv -yaml encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml')
        os.system(f'~/btrblocks/build/csvtobtr -create_btr -btr encoding_size/{base_name}/gen_data/btr/ -binary encoding_size/{base_name}/gen_data/binary/ -csv encoding_size/{base_name}/gen_data/{base_name}.csv -yaml encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml')
# Out:
# [2024-03-06 08:39:29.502] [info] Creating binary files in encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.01/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.01/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:39:38.031] [info] Creating btr files in encoding_size/int_r1000000_c20_sort0.01/gen_data/btr/
# [2024-03-06 08:39:41.773] [info] Creating binary files in encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.2/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.2/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:39:50.667] [info] Creating btr files in encoding_size/int_r1000000_c20_sort0.2/gen_data/btr/
# [2024-03-06 08:39:54.445] [info] Creating binary files in encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.4/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.4/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:40:02.916] [info] Creating btr files in encoding_size/int_r1000000_c20_sort0.4/gen_data/btr/
# [2024-03-06 08:40:06.516] [info] Creating binary files in encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.6/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.6/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:40:14.963] [info] Creating btr files in encoding_size/int_r1000000_c20_sort0.6/gen_data/btr/
# [2024-03-06 08:40:18.344] [info] Creating binary files in encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_sort0.8/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_sort0.8/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:40:26.354] [info] Creating btr files in encoding_size/int_r1000000_c20_sort0.8/gen_data/btr/
# ...
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.6/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.6/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:44:13.384] [info] Creating btr files in encoding_size/string_r1000000_c20_sort0.6/gen_data/btr/
# [2024-03-06 08:44:20.280] [info] Creating binary files in encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/
# column name = col0 , type = string
# column name = col1 , type = string
# column name = col2 , type = string
# column name = col3 , type = string
# column name = col4 , type = string
# column name = col5 , type = string
# column name = col6 , type = string
# column name = col7 , type = string
# column name = col8 , type = string
# column name = col9 , type = string
# column name = col10 , type = string
# column name = col11 , type = string
# column name = col12 , type = string
# column name = col13 , type = string
# column name = col14 , type = string
# column name = col15 , type = string
# column name = col16 , type = string
# column name = col17 , type = string
# column name = col18 , type = string
# column name = col19 , type = string
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort0.8/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort0.8/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:44:31.907] [info] Creating btr files in encoding_size/string_r1000000_c20_sort0.8/gen_data/btr/
# [2024-03-06 08:44:38.430] [info] Creating binary files in encoding_size/string_r1000000_c20_sort1/gen_data/binary/
# column name = col0 , type = string
# column name = col1 , type = string
# column name = col2 , type = string
# column name = col3 , type = string
# column name = col4 , type = string
# column name = col5 , type = string
# column name = col6 , type = string
# column name = col7 , type = string
# column name = col8 , type = string
# column name = col9 , type = string
# column name = col10 , type = string
# column name = col11 , type = string
# column name = col12 , type = string
# column name = col13 , type = string
# column name = col14 , type = string
# column name = col15 , type = string
# column name = col16 , type = string
# column name = col17 , type = string
# column name = col18 , type = string
# column name = col19 , type = string
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_sort1/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_sort1/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:44:48.294] [info] Creating btr files in encoding_size/string_r1000000_c20_sort1/gen_data/btr/

# %%
# collect size
os.chdir(dir_path)
os.system('rm outputs/stats.json')
def get_dir_size(path='.'):
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_sort{s}'
        output_stats = {}
        output_stats['type'] = t
        output_stats['feature'] = 'sort'
        output_stats['param'] = s
        output_stats['file'] = 'parquet'
        output_stats['size'] = os.path.getsize(f'{base_name}.parquet')
        parse_output(output_stats)
        output_stats['file'] = 'orc'
        output_stats['size'] = os.path.getsize(f'{base_name}.orc')
        parse_output(output_stats)
        output_stats['file'] = 'btrblocks'
        output_stats['size'] = get_dir_size(f'{base_name}/gen_data/btr')
        parse_output(output_stats)
collect_results()
os.system('mv outputs/stats.csv ../outputs/{}_{}.csv'.format('encoding_size_sort', timestamp))
# Out:
# 0
