# %%
import json
import os
import sys
import math
import datetime
import pathlib

dir_path = pathlib.Path(os.path.abspath('')).resolve()
print(dir_path)
HOME_DIR = str(dir_path).split('/OpenFormat')[0]

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

PROJ_SRC_DIR = f'{HOME_DIR}/OpenFormat/OpenFormat-Public'
sys.path.insert(1, f'{PROJ_SRC_DIR}')
from python.scripts.utils import *
# Out:
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/encoding_size

# %%
num_rows = 1000 * 1000
num_cols = 20
sort_list = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.4, 0.7]
type_list = ['int', 'float', 'string']

# %%
# %%time
# generate csv files
os.chdir(f'{PROJ_SRC_DIR}/benchmark/generator_v2')
# !pwd
for t in type_list:
    print(t)
    for s in sort_list:
        print(s)
        base_name = f'{t}_r{num_rows}_c{num_cols}_car{s}'
        # if os.path.exists(f'{dir_path}/{base_name}'):
        #     continue
        os.system(f'python3 gen_workloads.py \
            {t} {num_rows} {num_cols} {base_name} car {s}')
        os.system(f'cp -r {base_name} {dir_path} && \
            rm -r {base_name}')
os.chdir(dir_path)
# !pwd
# Out:
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/benchmark/generator_v2
# int
# 0.7
# Finish core dataset! 🎉🎉🎉🎉🎉🎉
# Generating Done!!
# 🤔 INFO: too many collisions in int_unique_list, 1 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 20803 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 567706 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 390841 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 412753 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 438 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 457581 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 411790 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 319933 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 234009 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 254374 values just use (max_value + 1)!
# 🤔 INFO: too many collisions in int_unique_list, 478647 values just use (max_value + 1)!
# /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/encoding_size
# CPU times: user 21 ms, sys: 16.4 ms, total: 37.4 ms
# Wall time: 9min 56s

# %%
pq_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/pq_encoding.json')
orc_config = enumerate_config(f'{PROJ_SRC_DIR}/python/experiments/orc_encoding.json')
pq_name_suffix = '_' + "_".join([str(i) for i in list(pq_config[0].values())]) + '.parquet'
orc_name_suffix = '_' + "_".join([str(i) for i in list(orc_config[0].values())]) + '.orc'
print(pq_config)
# Out:
# loading config from /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/experiments/pq_encoding.json ...
# loading config from /home/haoyuq/EvaluationOfColumnarFormats/OpenFormat/OpenFormat-Public/python/experiments/orc_encoding.json ...
# [{'compression': 'NONE', 'use_dictionary': True, 'dictionary_pagesize_limit': 2147483647, 'version': '2.6', 'data_page_version': '2.0'}]

# %%
# generate parquet and orc files
my_password = ''
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_car{s}'
        if os.path.exists(f'{dir_path}/{base_name}.orc'):
            continue
        os.system(f'cp {dir_path}/{base_name}/gen_data/{base_name}.csv data_gen')
        os.system(f'echo {my_password} | sudo -S /home/haoyuq/miniconda3/envs/gen/bin/python scripts/parquet_exp.py {base_name} pq_encoding -r=false -o=false')
        os.system(f'echo {my_password} | sudo -S /home/haoyuq/miniconda3/envs/gen/bin/python scripts/orc_exp.py {base_name} orc_encoding -r=false -o=false')
        # orc_schema = open(f'encoding/{base_name}/gen_data/{base_name}_orc_schema.txt', 'r').read()
        # os.system(f'{HOME_DIR}/orc/build/tools/src/csv-import \"{orc_schema}\" \
        #         encoding/{base_name}/gen_data/{base_name}.csv {base_name}.orc')
        os.system(f'mv {base_name}{pq_name_suffix} {dir_path}/{base_name}.parquet')
        os.system(f'mv {base_name}{orc_name_suffix} {dir_path}/{base_name}.orc')
        # os.system(f'mv {base_name}.orc encoding/{base_name}.orc')
os.chdir(dir_path)
# Out:
# [sudo] password for haoyuq:
# loading config from ./experiments/pq_encoding.json ...
# ----Running experiment: 1 out of 1----
# NONE_True_2147483647_2.6_2.0
# write parquet time (s): 1.0002436637878418
# [sudo] password for haoyuq:
# loading config from ./experiments/orc_encoding.json ...
# ----Running experiment:----
# UNCOMPRESSED_speed_1_2147486647
# write orc time (s): 15.038333654403687

# %%
import yaml
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_car{s}'
        arrow_schema_name = f'encoding_size/{base_name}/gen_data/{base_name}_arrow_schema.txt'
        with open(arrow_schema_name, 'r') as f:
            lines = f.readlines()
        columns = []
        cnt = 0
        for line in lines:
            if 'message' in line or '}' in line or len(line)==0:
                print(line)
                continue
            col_name = f'col{cnt}'
            col_type = None
            if 'String' in line:
                col_type = 'string'
            elif 'int' in line:
                col_type = 'integer'
            elif 'double' in line:
                col_type = 'double'
            if col_type is None:
                print(line)
                col_type = 'skip'
            cnt += 1
            columns.append({'name': col_name, 'type':col_type})
        with open(f'encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml','w') as f:
            yaml.dump({'columns':columns}, f)
# Out:
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }
# message schema {
#
# }

# %%
os.chdir(f'{PROJ_SRC_DIR}/python')
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_car{s}'
        os.system(f'mkdir encoding_size/{base_name}/gen_data/binary')
        os.system(f'mkdir encoding_size/{base_name}/gen_data/btr')
    
        os.system(f'~/btrblocks/build/csvtobtr -create_binary -binary encoding_size/{base_name}/gen_data/binary/ -csv encoding_size/{base_name}/gen_data/{base_name}.csv -yaml encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml')
        os.system(f'~/btrblocks/build/csvtobtr -create_btr -btr encoding_size/{base_name}/gen_data/btr/ -binary encoding_size/{base_name}/gen_data/binary/ -csv encoding_size/{base_name}/gen_data/{base_name}.csv -yaml encoding_size/{base_name}/gen_data/{base_name}_btrblocks_schema.yaml')
# Out:
# [2024-03-06 08:21:27.624] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.0001/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.0001/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:21:35.331] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.0001/gen_data/btr/
# [2024-03-06 08:21:38.183] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.001/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.001/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.001/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:21:46.419] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.001/gen_data/btr/
# [2024-03-06 08:21:49.487] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.01/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.01/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.01/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:21:58.101] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.01/gen_data/btr/
# [2024-03-06 08:22:01.265] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.1/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/1_col0.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/2_col1.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/3_col2.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/4_col3.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/5_col4.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/6_col5.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/7_col6.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/8_col7.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/9_col8.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/10_col9.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/11_col10.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/12_col11.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/13_col12.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/14_col13.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/15_col14.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/16_col15.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/17_col16.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/18_col17.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/19_col18.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [haoyu.debug.Parser] writing binary fileencoding_size/int_r1000000_c20_car0.1/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/int_r1000000_c20_car0.1/gen_data/binary/20_col19.integer
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 4 length=4000000
# [2024-03-06 08:22:10.728] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.1/gen_data/btr/
# [2024-03-06 08:22:14.312] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.2/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# exception thrown during parsing tuple_i = 40 column col_i = 9 name =col9 type = integer with column = 2150675601
# DUMP TUPLE
# 0 : 104942463
# 1 : 401260
# 2 : 59122
# 3 : 57577
# 4 : 2525887
# 5 :
# 6 : 48177
# 7 : 21619343
# 8 : 2150675601
# 9 : 42208
# 10 : 245002
# 11 : 3932425
# 12 : 1291624
# 13 : 106463
# 14 : 785004
# 15 : 2330162
# 16 : 115916
# 17 : 303192
# 18 : 167936
# 19 : 1638372
# stoi
# [2024-03-06 08:22:14.320] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.2/gen_data/btr/
# encoding_size/int_r1000000_c20_car0.2/gen_data/binary/1_col0.integer
# [2024-03-06 08:22:14.459] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.4/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# exception thrown during parsing tuple_i = 17 column col_i = 9 name =col9 type = integer with column = 2550380036
# DUMP TUPLE
# 0 : 6763664
# 1 : 341271
# 2 : 59122
# 3 : 57577
# 4 : 2525887
# 5 :
# 6 : 20590
# 7 : 22256
# 8 : 2550380036
# 9 : 181775
# 10 : 18631
# 11 : 2592802
# 12 : 2513999
# 13 : 106463
# 14 : 785004
# 15 : 2330162
# 16 : 1736822
# 17 : 303192
# 18 : 49810
# 19 : 1730724
# stoi
# [2024-03-06 08:22:14.464] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.4/gen_data/btr/
# encoding_size/int_r1000000_c20_car0.4/gen_data/binary/1_col0.integer
# fd != -1: No such file or directory
# csvtobtr: /home/haoyuq/btrblocks/btrblocks/storage/MMapVector.hpp:47: void btrblocks::mmapvector::Vector<T>::readBinary(const char*) [with T = int]: Assertion `false' failed.
# Aborted (core dumped)
# fd != -1: No such file or directory
# csvtobtr: /home/haoyuq/btrblocks/btrblocks/storage/MMapVector.hpp:47: void btrblocks::mmapvector::Vector<T>::readBinary(const char*) [with T = int]: Assertion `false' failed.
# Aborted (core dumped)
# fd != -1: No such file or directory
# csvtobtr: /home/haoyuq/btrblocks/btrblocks/storage/MMapVector.hpp:47: void btrblocks::mmapvector::Vector<T>::readBinary(const char*) [with T = int]: Assertion `false' failed.
# Aborted (core dumped)
# [2024-03-06 08:22:14.552] [info] Creating binary files in encoding_size/int_r1000000_c20_car0.7/gen_data/binary/
# column name = col0 , type = integer
# column name = col1 , type = integer
# column name = col2 , type = integer
# column name = col3 , type = integer
# column name = col4 , type = integer
# column name = col5 , type = integer
# column name = col6 , type = integer
# column name = col7 , type = integer
# column name = col8 , type = integer
# column name = col9 , type = integer
# column name = col10 , type = integer
# column name = col11 , type = integer
# column name = col12 , type = integer
# column name = col13 , type = integer
# column name = col14 , type = integer
# column name = col15 , type = integer
# column name = col16 , type = integer
# column name = col17 , type = integer
# column name = col18 , type = integer
# column name = col19 , type = integer
# exception thrown during parsing tuple_i = 28 column col_i = 9 name =col9 type = integer with column = 2299783096
# DUMP TUPLE
# 0 : 104942463
# 1 : 376164
# 2 : 56008
# 3 : 57577
# 4 : 2525887
# 5 :
# 6 : 50334
# 7 : 66348833
# 8 : 2299783096
# 9 : 180974
# 10 : 265636
# 11 : 6780588
# 12 : 439114
# 13 : 106463
# 14 : 89486
# 15 : 2330162
# 16 : 115916
# 17 : 551417
# 18 : 36819
# 19 : 16351664
# stoi
# [2024-03-06 08:22:14.557] [info] Creating btr files in encoding_size/int_r1000000_c20_car0.7/gen_data/btr/
# encoding_size/int_r1000000_c20_car0.7/gen_data/binary/1_col0.integer
# [2024-03-06 08:22:14.646] [info] Creating binary files in encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/
# column name = col0 , type = double
# column name = col1 , type = double
# column name = col2 , type = double
# column name = col3 , type = double
# column name = col4 , type = double
# column name = col5 , type = double
# column name = col6 , type = double
# column name = col7 , type = double
# column name = col8 , type = double
# column name = col9 , type = double
# column name = col10 , type = double
# column name = col11 , type = double
# column name = col12 , type = double
# column name = col13 , type = double
# column name = col14 , type = double
# column name = col15 , type = double
# column name = col16 , type = double
# column name = col17 , type = double
# column name = col18 , type = double
# column name = col19 , type = double
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/1_col0.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/2_col1.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/3_col2.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/4_col3.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/5_col4.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/6_col5.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/7_col6.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/8_col7.double
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 8 length=8000000
# [haoyu.debug.Parser] writing binary fileencoding_size/float_r1000000_c20_car0.0001/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# Writing binary file : encoding_size/float_r1000000_c20_car0.0001/gen_data/binary/9_col8.double
# ...
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.2/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.2/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:26:30.095] [info] Creating btr files in encoding_size/string_r1000000_c20_car0.2/gen_data/btr/
# [2024-03-06 08:26:42.843] [info] Creating binary files in encoding_size/string_r1000000_c20_car0.4/gen_data/binary/
# column name = col0 , type = string
# column name = col1 , type = string
# column name = col2 , type = string
# column name = col3 , type = string
# column name = col4 , type = string
# column name = col5 , type = string
# column name = col6 , type = string
# column name = col7 , type = string
# column name = col8 , type = string
# column name = col9 , type = string
# column name = col10 , type = string
# column name = col11 , type = string
# column name = col12 , type = string
# column name = col13 , type = string
# column name = col14 , type = string
# column name = col15 , type = string
# column name = col16 , type = string
# column name = col17 , type = string
# column name = col18 , type = string
# column name = col19 , type = string
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.4/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.4/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:27:07.639] [info] Creating btr files in encoding_size/string_r1000000_c20_car0.4/gen_data/btr/
# [2024-03-06 08:27:21.083] [info] Creating binary files in encoding_size/string_r1000000_c20_car0.7/gen_data/binary/
# column name = col0 , type = string
# column name = col1 , type = string
# column name = col2 , type = string
# column name = col3 , type = string
# column name = col4 , type = string
# column name = col5 , type = string
# column name = col6 , type = string
# column name = col7 , type = string
# column name = col8 , type = string
# column name = col9 , type = string
# column name = col10 , type = string
# column name = col11 , type = string
# column name = col12 , type = string
# column name = col13 , type = string
# column name = col14 , type = string
# column name = col15 , type = string
# column name = col16 , type = string
# column name = col17 , type = string
# column name = col18 , type = string
# column name = col19 , type = string
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/1_col0.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/1_col0.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/2_col1.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/2_col1.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/3_col2.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/3_col2.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/4_col3.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/4_col3.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/5_col4.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/5_col4.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/6_col5.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/6_col5.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/7_col6.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/7_col6.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/8_col7.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/8_col7.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/9_col8.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/9_col8.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/10_col9.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/10_col9.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/11_col10.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/11_col10.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/12_col11.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/12_col11.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/13_col12.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/13_col12.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/14_col13.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/14_col13.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/15_col14.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/15_col14.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/16_col15.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/16_col15.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/17_col16.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/17_col16.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/18_col17.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/18_col17.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/19_col18.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/19_col18.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [haoyu.debug.Parser] writing binary fileencoding_size/string_r1000000_c20_car0.7/gen_data/binary/20_col19.bitmap
# Writing binary file : encoding_size/string_r1000000_c20_car0.7/gen_data/binary/20_col19.bitmap
# [haoyu.debug.writeBinary] v.size 1000000 sizeof(T) 1 length=1000000
# [2024-03-06 08:27:45.847] [info] Creating btr files in encoding_size/string_r1000000_c20_car0.7/gen_data/btr/

# %%
# collect size
os.chdir(dir_path)
os.system('rm outputs/stats.json')
def get_dir_size(path='.'):
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total
    
for t in type_list:
    for s in sort_list:
        base_name = f'{t}_r{num_rows}_c{num_cols}_car{s}'
        output_stats = {}
        output_stats['type'] = t
        output_stats['feature'] = 'car'
        output_stats['param'] = s
        output_stats['file'] = 'parquet'
        output_stats['size'] = os.path.getsize(f'{base_name}.parquet')
        parse_output(output_stats)
        output_stats['file'] = 'orc'
        output_stats['size'] = os.path.getsize(f'{base_name}.orc')
        parse_output(output_stats)
        output_stats['file'] = 'btrblocks'
        output_stats['size'] = get_dir_size(f'{base_name}/gen_data/btr')
        parse_output(output_stats)
collect_results()
os.system('mv outputs/stats.csv ../outputs/{}_{}.csv'.format('encoding_size_car', timestamp))
# Out:
# 0
